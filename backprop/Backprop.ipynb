# %%
#@markdown # Imports
#@markdown ### Bring in many import packages 

from sympy import *
import numpy as np
from tqdm import tqdm
import math
from IPython.display import display, HTML, Javascript

# %%
#@markdown # Define HCO Class
#@markdown ## Construct a new HCO object 
#@markdown ### `history: bool`: This is if the historical weights must be saved
class HCO:

  def __init__(self, history = False, weights = None, base = 0):
    """
    Construct a new HCO object
    :param history: This is if the historical must be saved
    """
    if weights is None:
      self.weights = np.random.uniform(-1,1,(8))
    else:
      self.weights = weights
    self.phi = Symbol("phi")
    self.syms = symbols("A:H")
    self.eq = self.generate_eq()
    self.eqs = solve(self.eq,self.phi)
    self.y = 0.25
    self.lr = 1
    self.history = history
    self.historical = []
    self.optim_steps = base
    self.v_curr = 0
    self.s_curr = 0

  # Generate dphi/dt equation see below
  def generate_eq(self):
    eq = 0
    h = lambda n: -n*(n-0.25) * (n-1)
    for i,val in enumerate(self.syms):
      add = ((i % 2) == 1) * 0.5
      neg = (i > 3) * 2 -1
      eq+=h(neg* self.phi + add) * val * neg * -1
    return eq
  
  # Finds zero equation that works
  def ret_eq(self, params):
    vals = []
    out = []
    for eq in self.eqs:
      val = eq.subs(params).n()
      if type(round(val, 10)) == Float:
        vals.append(round(val,10))
        out.append(eq)
    ind = np.abs(np.array(vals)- 0.25).argmin()
    return out[ind], vals[ind]

  # loss comparing neural circuit phi value to 0.25. Also used in backprop.
  def loss(self, yhat):
    return (self.y-yhat)**2

  def loss_prime(self, yhat):
    return (yhat - self.y)*2

  def get_eq(self):
    params = dict(zip(self.syms, self.weights))
    return self.eq.subs(params)

  def print_eq(self):
    params = dict(zip(self.syms, self.weights))
    return self.eq.subs(params).subs({self.phi: Symbol("x")})

  def get_params(self):
    return dict(zip(self.syms, self.weights))

  def backprop_diff(self):
    params = dict(zip(self.syms, self.weights))

    zero = self.ret_eq(params)[1]
    value = 1
  
    while value > 0:
      params = dict(zip(self.syms, self.weights))
      zero = self.ret_eq(params)[1]
      equation = self.eq.diff(self.phi).subs({self.phi: zero})

      value = equation.subs(params).n()
      diff = []
      for sym in self.syms:
        dsym = equation.diff(sym).subs(params).n()
        diff.append(dsym * -1)
      self.weights = self.weights + np.array(diff)

    print("> Done")

  def backprop_optim(self, steps, graph):
    # progress bar
    tq = tqdm(range(steps)) if not graph else range(steps)
    for step in tq:

      params = dict(zip(self.syms, self.weights))
      eq,val = self.ret_eq(params)
      
      # dL/dphi
      loss_grad = round(self.loss_prime(val),10)
      loss = round(self.loss(val),10)

      if loss == 0:
        break

      if graph:
        display(Javascript('addData('+str(step)+','+str(abs(loss))+')'))
      else:
        tq.set_description_str(f"Loss: {abs(loss)}")

      diff = []
      for symbol in self.syms:
        d = round(eq.diff(symbol).subs(params).n(),10)
        # dL/dphi * dphi/dA etc.
        grad = self.adam_optimzer(d * loss_grad)
        diff.append(grad * -1 * self.lr)
      if self.history:
        self.historical.append(self.weights)
      self.weights = self.weights+ np.array(diff)
    return self.historical

  def save_weights(self):
    np.save(f"backprop_weights_{self.optim_steps}.npy", self.weights)
  
  @staticmethod
  def load(path: str, history: bool=False):
    stp = int(path.split("_")[-1])
    return HCO(history, np.load(path,allow_pickle=True), base=stp)
  
  def optim(self, steps, graph = False):
    print("Initializing function for steady states")
    self.backprop_diff()
    print("Starting weights optimization")

    self.backprop_optim(steps, graph)
    self.optim_steps += steps
  def adam_optimzer(self,theta_curr):
    beta1 = 0.9
    beta2 = 0.99
    epsilon = 1e-8
    self.s_curr = beta2 * self.s_curr +(1-beta2)*(np.power(theta_curr, 2))
    self.v_curr = beta1 * self.v_curr + (1-beta1)*theta_curr
    return self.v_curr / math.sqrt(self.s_curr + epsilon)
  def rmsprop(self,theta_curr):
    epsilon = 1e-8
    beta = 0.9
    self.s_curr = beta * self.s_curr +(1-beta)*(np.power(theta_curr, 2))
    return theta_curr / np.sqrt(self.s_curr + epsilon)
  def return_matrices(self):
    gamma = np.zeros((2,2)).tolist()
    alpha = np.zeros_like(gamma).tolist()
    for ind,w in enumerate(self.weights[:4]):
      gamma[ind>1][ind%3 != 0] = w
    for ind,w in enumerate(self.weights[4:]):
      alpha[ind >1][ind%3 != 0] = w
    return alpha, gamma

# %%
#@markdown # Run the Backprop Algorithm
#@markdown ### loss should be decreasing.
#@markdown Run this cell if you want to train from scratch.

#@markdown Defines number of optimization iterations
STEPS = 2000 #@param {type:"slider", min:0, max:2000, step:10}
#@markdown Defines if the weights should be saved at every step
HISTORY = False #@param {type:"boolean"}
#@markdown Defines if the realtime loss graph should be plotted. If unchecked it defaults to a progress bar.
GRAPH = False #@param {type:"boolean"}
#@markdown Defines if the weights should be saved to disk for later use.
SAVE = False #@param {type:"boolean"}

hco = HCO(HISTORY)
hco.optim(STEPS, GRAPH)
if SAVE:
  hco.save_weights()
print(hco.return_matrices())
# Out:
# Initializing function for steady states
# > Done
# Starting weights optimization
# Loss: 0.0071775642:  71%|███████   | 1417/2000 [17:21<07:08,  1.36it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/assumptions.py:479, in make_property.<locals>.getit(self)
#     478 try:
# --> 479     return self._assumptions[fact]
#     480 except KeyError:
#
# KeyError: 'infinite'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/assumptions.py:479, in make_property.<locals>.getit(self)
#     478 try:
# --> 479     return self._assumptions[fact]
#     480 except KeyError:
#
# KeyError: 'infinite'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/assumptions.py:479, in make_property.<locals>.getit(self)
#     478 try:
# --> 479     return self._assumptions[fact]
#     480 except KeyError:
#
# KeyError: 'extended_negative'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/assumptions.py:479, in make_property.<locals>.getit(self)
#     478 try:
# --> 479     return self._assumptions[fact]
#     480 except KeyError:
#
# KeyError: 'complex'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 15
#      12 SAVE = False #@param {type:"boolean"}
#      14 hco = HCO(HISTORY)
# ---> 15 hco.optim(STEPS, GRAPH)
#      16 if SAVE:
#      17   hco.save_weights()
#
# Cell In[5], line 133, in HCO.optim(self, steps, graph)
#     130 if graph:
#     131   configure_browser_state()
# --> 133 self.backprop_optim(steps, graph)
#     134 self.optim_steps += steps
#
# Cell In[5], line 93, in HCO.backprop_optim(self, steps, graph)
#      90 for step in tq:
#      92   params = dict(zip(self.syms, self.weights))
# ---> 93   eq,val = self.ret_eq(params)
#      95   # dL/dphi
#      96   loss_grad = round(self.loss_prime(val),10)
#
# Cell In[5], line 42, in HCO.ret_eq(self, params)
#      40 out = []
#      41 for eq in self.eqs:
# ---> 42   val = eq.subs(params).n()
#      43   if type(round(val, 10)) == Float:
#      44     vals.append(round(val,10))
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/basic.py:997, in Basic.subs(self, *args, **kwargs)
#     995 rv = self
#     996 for old, new in sequence:
# --> 997     rv = rv._subs(old, new, **kwargs)
#     998     if not isinstance(rv, Basic):
#     999         break
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/cache.py:70, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      67 @wraps(func)
#      68 def wrapper(*args, **kwargs):
#      69     try:
# ---> 70         retval = cfunc(*args, **kwargs)
#      71     except TypeError as e:
#      72         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/basic.py:1111, in Basic._subs(self, old, new, **hints)
#    1109 rv = self._eval_subs(old, new)
#    1110 if rv is None:
# -> 1111     rv = fallback(self, old, new)
#    1112 return rv
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/basic.py:1083, in Basic._subs.<locals>.fallback(self, old, new)
#    1081 if not hasattr(arg, '_eval_subs'):
#    1082     continue
# -> 1083 arg = arg._subs(old, new, **hints)
#    1084 if not _aresame(arg, args[i]):
#    1085     hit = True
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/cache.py:70, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      67 @wraps(func)
#      68 def wrapper(*args, **kwargs):
#      69     try:
# ---> 70         retval = cfunc(*args, **kwargs)
#      71     except TypeError as e:
#      72         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/basic.py:1111, in Basic._subs(self, old, new, **hints)
#    1109 rv = self._eval_subs(old, new)
#    1110 if rv is None:
# -> 1111     rv = fallback(self, old, new)
#    1112 return rv
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/basic.py:1083, in Basic._subs.<locals>.fallback(self, old, new)
#    1081 if not hasattr(arg, '_eval_subs'):
#    1082     continue
# -> 1083 arg = arg._subs(old, new, **hints)
#    1084 if not _aresame(arg, args[i]):
#    1085     hit = True
#
#     [... skipping similar frames: Basic._subs at line 1111 (5 times), __cacheit.<locals>.func_wrapper.<locals>.wrapper at line 70 (5 times), Basic._subs.<locals>.fallback at line 1083 (4 times)]
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/basic.py:1083, in Basic._subs.<locals>.fallback(self, old, new)
#    1081 if not hasattr(arg, '_eval_subs'):
#    1082     continue
# -> 1083 arg = arg._subs(old, new, **hints)
#    1084 if not _aresame(arg, args[i]):
#    1085     hit = True
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/cache.py:70, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      67 @wraps(func)
#      68 def wrapper(*args, **kwargs):
#      69     try:
# ---> 70         retval = cfunc(*args, **kwargs)
#      71     except TypeError as e:
#      72         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/basic.py:1111, in Basic._subs(self, old, new, **hints)
#    1109 rv = self._eval_subs(old, new)
#    1110 if rv is None:
# -> 1111     rv = fallback(self, old, new)
#    1112 return rv
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/basic.py:1088, in Basic._subs.<locals>.fallback(self, old, new)
#    1086         args[i] = arg
#    1087 if hit:
# -> 1088     rv = self.func(*args)
#    1089     hack2 = hints.get('hack2', False)
#    1090     if hack2 and self.is_Mul and not rv.is_Mul:  # 2-arg hack
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/cache.py:70, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      67 @wraps(func)
#      68 def wrapper(*args, **kwargs):
#      69     try:
# ---> 70         retval = cfunc(*args, **kwargs)
#      71     except TypeError as e:
#      72         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/power.py:371, in Pow.__new__(cls, b, e, evaluate)
#     367         if s.is_Number and s and den == \
#     368                 log(-factor_terms(b, sign=False)) + s*S.ImaginaryUnit*S.Pi:
#     369             return S.Exp1**(c*num)
# --> 371 obj = b._eval_power(e)
#     372 if obj is not None:
#     373     return obj
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/add.py:458, in Add._eval_power(self, e)
#     456 from .evalf import pure_complex
#     457 from .relational import is_eq
# --> 458 if len(self.args) == 2 and any(_.is_infinite for _ in self.args):
#     459     if e.is_zero is False and is_eq(e, S.One) is False:
#     460         # looking for literal a + I*b
#     461         a, b = self.args
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/add.py:458, in <genexpr>(.0)
#     456 from .evalf import pure_complex
#     457 from .relational import is_eq
# --> 458 if len(self.args) == 2 and any(_.is_infinite for _ in self.args):
#     459     if e.is_zero is False and is_eq(e, S.One) is False:
#     460         # looking for literal a + I*b
#     461         a, b = self.args
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/assumptions.py:483, in make_property.<locals>.getit(self)
#     481 if self._assumptions is self.default_assumptions:
#     482     self._assumptions = self.default_assumptions.copy()
# --> 483 return _ask(fact, self)
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/assumptions.py:539, in _ask(fact, obj)
#     537 handler_i = handler_map.get(fact_i)
#     538 if handler_i is not None:
# --> 539     fact_i_value = handler_i(obj)
#     541 # If we get a new value for fact_i then we should update our knowledge
#     542 # of fact_i as well as any related facts that can be inferred using the
#     543 # inference rules connecting the fact_i and any other fact values that
#     544 # are already known.
#     545 if fact_i_value is not None:
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/mul.py:1285, in Mul._eval_is_infinite(self)
#    1284 def _eval_is_infinite(self):
# -> 1285     if any(a.is_infinite for a in self.args):
#    1286         if any(a.is_zero for a in self.args):
#    1287             return S.NaN.is_infinite
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/mul.py:1285, in <genexpr>(.0)
#    1284 def _eval_is_infinite(self):
# -> 1285     if any(a.is_infinite for a in self.args):
#    1286         if any(a.is_zero for a in self.args):
#    1287             return S.NaN.is_infinite
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/assumptions.py:483, in make_property.<locals>.getit(self)
#     481 if self._assumptions is self.default_assumptions:
#     482     self._assumptions = self.default_assumptions.copy()
# --> 483 return _ask(fact, self)
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/assumptions.py:539, in _ask(fact, obj)
#     537 handler_i = handler_map.get(fact_i)
#     538 if handler_i is not None:
# --> 539     fact_i_value = handler_i(obj)
#     541 # If we get a new value for fact_i then we should update our knowledge
#     542 # of fact_i as well as any related facts that can be inferred using the
#     543 # inference rules connecting the fact_i and any other fact values that
#     544 # are already known.
#     545 if fact_i_value is not None:
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/power.py:560, in Pow._eval_is_negative(self)
#     559 def _eval_is_negative(self):
# --> 560     ext_neg = Pow._eval_is_extended_negative(self)
#     561     if ext_neg is True:
#     562         return self.is_finite
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/power.py:598, in Pow._eval_is_extended_negative(self)
#     596     if self.base.is_complex or self.base.is_extended_real:
#     597         return False
# --> 598 if self.base.is_extended_negative:
#     599     if self.exp.is_odd and self.base.is_finite:
#     600         return True
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/assumptions.py:483, in make_property.<locals>.getit(self)
#     481 if self._assumptions is self.default_assumptions:
#     482     self._assumptions = self.default_assumptions.copy()
# --> 483 return _ask(fact, self)
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/assumptions.py:539, in _ask(fact, obj)
#     537 handler_i = handler_map.get(fact_i)
#     538 if handler_i is not None:
# --> 539     fact_i_value = handler_i(obj)
#     541 # If we get a new value for fact_i then we should update our knowledge
#     542 # of fact_i as well as any related facts that can be inferred using the
#     543 # inference rules connecting the fact_i and any other fact values that
#     544 # are already known.
#     545 if fact_i_value is not None:
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/add.py:639, in Add.<lambda>(self)
#     635 _eval_is_real = lambda self: _fuzzy_group(
#     636     (a.is_real for a in self.args), quick_exit=True)
#     637 _eval_is_extended_real = lambda self: _fuzzy_group(
#     638     (a.is_extended_real for a in self.args), quick_exit=True)
# --> 639 _eval_is_complex = lambda self: _fuzzy_group(
#     640     (a.is_complex for a in self.args), quick_exit=True)
#     641 _eval_is_antihermitian = lambda self: _fuzzy_group(
#     642     (a.is_antihermitian for a in self.args), quick_exit=True)
#     643 _eval_is_finite = lambda self: _fuzzy_group(
#     644     (a.is_finite for a in self.args), quick_exit=True)
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/logic.py:81, in _fuzzy_group(args, quick_exit)
#      44 """Return True if all args are True, None if there is any None else False
#      45 unless ``quick_exit`` is True (then return None as soon as a second False
#      46 is seen.
#    (...)
#      78
#      79 """
#      80 saw_other = False
# ---> 81 for a in args:
#      82     if a is True:
#      83         continue
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/add.py:640, in <genexpr>(.0)
#     635 _eval_is_real = lambda self: _fuzzy_group(
#     636     (a.is_real for a in self.args), quick_exit=True)
#     637 _eval_is_extended_real = lambda self: _fuzzy_group(
#     638     (a.is_extended_real for a in self.args), quick_exit=True)
#     639 _eval_is_complex = lambda self: _fuzzy_group(
# --> 640     (a.is_complex for a in self.args), quick_exit=True)
#     641 _eval_is_antihermitian = lambda self: _fuzzy_group(
#     642     (a.is_antihermitian for a in self.args), quick_exit=True)
#     643 _eval_is_finite = lambda self: _fuzzy_group(
#     644     (a.is_finite for a in self.args), quick_exit=True)
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/assumptions.py:483, in make_property.<locals>.getit(self)
#     481 if self._assumptions is self.default_assumptions:
#     482     self._assumptions = self.default_assumptions.copy()
# --> 483 return _ask(fact, self)
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/site-packages/sympy/core/assumptions.py:567, in _ask(fact, obj)
#     559 # Extend the queue with other facts that might determine fact_i. Here
#     560 # we randomise the order of the facts that are checked. This should not
#     561 # lead to any non-determinism if all handlers are logically consistent
#    (...)
#     564 # call to shuffle. These are pushed to the back of the queue meaning
#     565 # that the inference graph is traversed in breadth-first order.
#     566 new_facts_to_check = list(_assume_rules.prereq[fact_i] - facts_queued)
# --> 567 shuffle(new_facts_to_check)
#     568 facts_to_check.extend(new_facts_to_check)
#     569 facts_queued.update(new_facts_to_check)
#
# File ~/opt/anaconda3/envs/nl_evo/lib/python3.8/random.py:304, in Random.shuffle(self, x, random)
#     302 if random is None:
#     303     randbelow = self._randbelow
# --> 304     for i in reversed(range(1, len(x))):
#     305         # pick an element in x[:i+1] with which to exchange x[i]
#     306         j = randbelow(i+1)
#     307         x[i], x[j] = x[j], x[i]
#
# KeyboardInterrupt:

# %%
print(hco.return_matrices())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(hco.return_matrices())
#
# NameError: name 'hco' is not defined

# %%
#@markdown # Load Weights
#@markdown Run this cell if you want to train from a saved weights file. 
#@markdown Check the file explorer on the right for the file name following
#@markdown Follows the following format `backprop_weights_{step number}.npy`

filename = "" #@param {type:"string"}
#@markdown Defines number of optimization iterations
STEPS = 300 #@param {type:"slider", min:0, max:2000, step:10}
#@markdown Defines if the weights should be saved at every step
HISTORY = True #@param {type:"boolean"}
#@markdown Defines if the realtime loss graph should be plotted. If unchecked it defaults to a progress bar.
GRAPH = False #@param {type:"boolean"}
#@markdown Defines if the weights should be saved to disk for later use.
SAVE = False #@param {type:"boolean"}
hco = HCO.load(filename, HISTORY)
hco.optim(STEPS, GRAPH)

if SAVE:
  hco.save_weights()
